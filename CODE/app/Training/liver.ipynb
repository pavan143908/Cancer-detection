# %% [markdown]
# ## Importing libraries

# %%
from keras.models import Sequential, load_model
import tensorflow as tf
from keras.layers import Convolution2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import MaxPooling2D, Conv2D, MaxPool2D, Activation, GlobalAveragePooling2D, BatchNormalization, Dropout
from matplotlib import pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Data pre-processing

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

print("\nTraining the data...\n")
training_set = train_datagen.flow_from_directory('../liver data/train',
                                                 target_size=(224,224),
                                                 batch_size=12,
                                                 class_mode='categorical'
                                                 )

test_set = train_datagen.flow_from_directory('../liver data/test',
                                            target_size=(224,224),
                                            batch_size=12,
                                            class_mode='categorical'
                                            )
print("\n Testing the data.....\n")
# Out:
# Training the data...
#
# Found 2201 images belonging to 2 classes.
# Found 829 images belonging to 2 classes.
#
#  Testing the data.....

# %% [markdown]
# ## CNN Model building

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='Same', activation='relu', input_shape=(224,224, 3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=96, kernel_size=(3,3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters=96, kernel_size=(3,3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(2, activation="softmax"))

model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


history=model.fit(training_set,epochs = 30,validation_data = test_set,verbose = 1)

model.save(r"models/CNN.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 96)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18816)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9634304
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 9,793,154
# Trainable params: 9,793,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 184/184 [==============================] - 354s 2s/step - loss: 0.4731 - accuracy: 0.7606 - val_loss: 0.2660 - val_accuracy: 0.8673
# Epoch 2/30
# 184/184 [==============================] - 143s 775ms/step - loss: 0.2293 - accuracy: 0.9064 - val_loss: 0.1574 - val_accuracy: 0.9337
# Epoch 3/30
# 184/184 [==============================] - 128s 695ms/step - loss: 0.1692 - accuracy: 0.9405 - val_loss: 0.1644 - val_accuracy: 0.9409
# Epoch 4/30
# 184/184 [==============================] - 141s 766ms/step - loss: 0.1002 - accuracy: 0.9614 - val_loss: 0.0326 - val_accuracy: 0.9867
# Epoch 5/30
# 184/184 [==============================] - 151s 820ms/step - loss: 0.0568 - accuracy: 0.9777 - val_loss: 0.0268 - val_accuracy: 0.9940
# Epoch 6/30
# 184/184 [==============================] - 131s 711ms/step - loss: 0.0551 - accuracy: 0.9791 - val_loss: 0.0114 - val_accuracy: 0.9976
# Epoch 7/30
# 184/184 [==============================] - 151s 818ms/step - loss: 0.0231 - accuracy: 0.9909 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 8/30
# 184/184 [==============================] - 140s 764ms/step - loss: 0.0560 - accuracy: 0.9827 - val_loss: 0.0133 - val_accuracy: 0.9940
# Epoch 9/30
# 184/184 [==============================] - 141s 768ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.0226 - val_accuracy: 0.9928
# Epoch 10/30
# 184/184 [==============================] - 150s 814ms/step - loss: 0.0386 - accuracy: 0.9855 - val_loss: 0.0181 - val_accuracy: 0.9952
# Epoch 11/30
# 184/184 [==============================] - 132s 713ms/step - loss: 0.0515 - accuracy: 0.9818 - val_loss: 0.0601 - val_accuracy: 0.9903
# Epoch 12/30
# 184/184 [==============================] - 150s 814ms/step - loss: 0.0245 - accuracy: 0.9905 - val_loss: 0.0174 - val_accuracy: 0.9952
# Epoch 13/30
# 184/184 [==============================] - 141s 768ms/step - loss: 0.0764 - accuracy: 0.9768 - val_loss: 0.0191 - val_accuracy: 0.9940
# Epoch 14/30
# 184/184 [==============================] - 141s 766ms/step - loss: 0.0370 - accuracy: 0.9882 - val_loss: 0.0072 - val_accuracy: 0.9976
# Epoch 15/30
# 184/184 [==============================] - 151s 818ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0188 - val_accuracy: 0.9952
# Epoch 16/30
# 184/184 [==============================] - 131s 710ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 17/30
# 184/184 [==============================] - 150s 816ms/step - loss: 3.6606e-04 - accuracy: 1.0000 - val_loss: 2.0446e-04 - val_accuracy: 1.0000
# Epoch 18/30
# 184/184 [==============================] - 142s 770ms/step - loss: 5.0542e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 0.9988
# Epoch 19/30
# 184/184 [==============================] - 141s 766ms/step - loss: 2.6785e-04 - accuracy: 1.0000 - val_loss: 9.6599e-05 - val_accuracy: 1.0000
# Epoch 20/30
# 184/184 [==============================] - 150s 814ms/step - loss: 0.0393 - accuracy: 0.9868 - val_loss: 0.0113 - val_accuracy: 0.9976
# Epoch 21/30
# 184/184 [==============================] - 131s 711ms/step - loss: 0.0322 - accuracy: 0.9923 - val_loss: 0.0037 - val_accuracy: 0.9988
# Epoch 22/30
# 184/184 [==============================] - 151s 821ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 3.0676e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 184/184 [==============================] - 142s 770ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0112 - val_accuracy: 0.9976
# Epoch 24/30
# 184/184 [==============================] - 140s 758ms/step - loss: 0.0358 - accuracy: 0.9855 - val_loss: 0.0326 - val_accuracy: 0.9928
# Epoch 25/30
# 184/184 [==============================] - 150s 812ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 26/30
# 184/184 [==============================] - 131s 710ms/step - loss: 7.4497e-04 - accuracy: 1.0000 - val_loss: 6.7488e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 184/184 [==============================] - 153s 833ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0113 - val_accuracy: 0.9964
# Epoch 28/30
# 184/184 [==============================] - 146s 789ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0056 - val_accuracy: 0.9988
# Epoch 29/30
# 184/184 [==============================] - 142s 773ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0387 - val_accuracy: 0.9891
# Epoch 30/30
# 184/184 [==============================] - 154s 834ms/step - loss: 0.0317 - accuracy: 0.9877 - val_loss: 7.2417e-04 - val_accuracy: 1.0000

# %% [markdown]
# ## Plotting graphs

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['accuracy'],'r',label='Testing accuracy',color='green')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/CNN_acc.png")
plt.show()


plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['loss'],'r',label='Testing accuracy',color='green')
plt.plot(history.history['val_loss'],label='validation accuracy')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/CNN_loss.png")
plt.show()


acc=history.history['accuracy'][-1]
print(acc)
# Out:
# 0.9877328276634216

# %% [markdown]
# ## Mobilenet model building

# %%
base_model = tf.keras.applications.MobileNet(input_shape=(224,224, 3), include_top=False,
                          weights='imagenet')
model1 = Sequential()
model1.add(base_model)
model1.add(GlobalAveragePooling2D())
model1.add(Dense(64, activation='relu'))
model1.add(BatchNormalization())
model1.add(Dropout(0.2))
model1.add(Dense(2, activation='sigmoid'))
model1.summary()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


history=model.fit_generator(training_set,epochs = 30,validation_data = test_set,verbose = 1)

model.save("models/mobilenet.h5")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                65600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 3,294,850
# Trainable params: 3,272,834
# Non-trainable params: 22,016
# _________________________________________________________________
# c:\Program Files\Python36\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 184/184 [==============================] - 139s 750ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 2/30
# 184/184 [==============================] - 160s 866ms/step - loss: 0.0296 - accuracy: 0.9927 - val_loss: 5.4846e-04 - val_accuracy: 1.0000
# Epoch 3/30
# 184/184 [==============================] - 146s 794ms/step - loss: 8.4046e-04 - accuracy: 0.9995 - val_loss: 9.1903e-05 - val_accuracy: 1.0000
# Epoch 4/30
# 184/184 [==============================] - 145s 787ms/step - loss: 5.7941e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9988
# Epoch 5/30
# 184/184 [==============================] - 158s 856ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.0181 - val_accuracy: 0.9952
# Epoch 6/30
# 184/184 [==============================] - 141s 766ms/step - loss: 0.0162 - accuracy: 0.9959 - val_loss: 1.9945e-04 - val_accuracy: 1.0000
# Epoch 7/30
# 184/184 [==============================] - 156s 847ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 1.7175e-05 - val_accuracy: 1.0000
# Epoch 8/30
# 184/184 [==============================] - 147s 795ms/step - loss: 1.2538e-04 - accuracy: 1.0000 - val_loss: 1.5977e-04 - val_accuracy: 1.0000
# Epoch 9/30
# 184/184 [==============================] - 145s 786ms/step - loss: 3.1489e-05 - accuracy: 1.0000 - val_loss: 1.4504e-05 - val_accuracy: 1.0000
# Epoch 10/30
# 184/184 [==============================] - 151s 820ms/step - loss: 2.7030e-05 - accuracy: 1.0000 - val_loss: 7.8508e-05 - val_accuracy: 1.0000
# Epoch 11/30
# 184/184 [==============================] - 132s 715ms/step - loss: 7.9880e-06 - accuracy: 1.0000 - val_loss: 4.3455e-06 - val_accuracy: 1.0000
# Epoch 12/30
# 184/184 [==============================] - 150s 813ms/step - loss: 1.4252e-05 - accuracy: 1.0000 - val_loss: 4.1961e-06 - val_accuracy: 1.0000
# Epoch 13/30
# 184/184 [==============================] - 146s 791ms/step - loss: 8.2928e-06 - accuracy: 1.0000 - val_loss: 9.7714e-07 - val_accuracy: 1.0000
# Epoch 14/30
# 184/184 [==============================] - 139s 754ms/step - loss: 1.9779e-06 - accuracy: 1.0000 - val_loss: 9.9494e-06 - val_accuracy: 1.0000
# Epoch 15/30
# 184/184 [==============================] - 153s 829ms/step - loss: 1.0818e-06 - accuracy: 1.0000 - val_loss: 1.7917e-06 - val_accuracy: 1.0000
# Epoch 16/30
# 184/184 [==============================] - 143s 777ms/step - loss: 1.0260e-06 - accuracy: 1.0000 - val_loss: 1.3003e-06 - val_accuracy: 1.0000
# Epoch 17/30
# 184/184 [==============================] - 151s 822ms/step - loss: 1.2962e-05 - accuracy: 1.0000 - val_loss: 2.0513e-05 - val_accuracy: 1.0000
# Epoch 18/30
# 184/184 [==============================] - 147s 799ms/step - loss: 5.8819e-05 - accuracy: 1.0000 - val_loss: 3.4841e-07 - val_accuracy: 1.0000
# Epoch 19/30
# 184/184 [==============================] - 140s 758ms/step - loss: 1.2130e-06 - accuracy: 1.0000 - val_loss: 2.0774e-06 - val_accuracy: 1.0000
# Epoch 20/30
# 184/184 [==============================] - 173s 945ms/step - loss: 4.4545e-07 - accuracy: 1.0000 - val_loss: 1.4153e-06 - val_accuracy: 1.0000
# Epoch 21/30
# 184/184 [==============================] - 144s 781ms/step - loss: 0.1292 - accuracy: 0.9573 - val_loss: 0.1096 - val_accuracy: 0.9638
# Epoch 22/30
# 184/184 [==============================] - 145s 790ms/step - loss: 0.1459 - accuracy: 0.9546 - val_loss: 0.0242 - val_accuracy: 0.9928
# Epoch 23/30
# 184/184 [==============================] - 156s 846ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0231 - val_accuracy: 0.9940
# Epoch 24/30
# 184/184 [==============================] - 136s 740ms/step - loss: 0.0178 - accuracy: 0.9927 - val_loss: 0.0122 - val_accuracy: 0.9964
# Epoch 25/30
# 184/184 [==============================] - 153s 831ms/step - loss: 0.0080 - accuracy: 0.9986 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 26/30
# 184/184 [==============================] - 146s 791ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 2.3295e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 184/184 [==============================] - 146s 795ms/step - loss: 6.6505e-04 - accuracy: 1.0000 - val_loss: 2.1679e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 184/184 [==============================] - 159s 862ms/step - loss: 1.4923e-04 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9988
# Epoch 29/30
# 184/184 [==============================] - 134s 726ms/step - loss: 3.6137e-04 - accuracy: 1.0000 - val_loss: 1.6664e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 184/184 [==============================] - 149s 812ms/step - loss: 3.2260e-04 - accuracy: 1.0000 - val_loss: 7.1524e-05 - val_accuracy: 1.0000

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['accuracy'],'r',label='Testing accuracy',color='green')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/mobilenet_acc.png")
plt.show()



plt.style.use("ggplot")
plt.figure()
plt.plot(history.history['loss'],'r',label='Testing accuracy',color='green')
plt.plot(history.history['val_loss'],label='validation accuracy')
plt.xlabel('# Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("models/mobilenet_loss.png")
plt.show()


acc=history.history['accuracy'][-1]
print(acc)
# Out:
# 1.0
